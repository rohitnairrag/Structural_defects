# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
image_link=r"C:\Users\Admin\Downloads\honeycomb.jpg"

# %%
defect_image=Image.open(image_link)

# %%
defect_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
# lets see if we can identify the defected area in 
import google.generativeai as genai
import os

# %%
genai.configure(api_key=os.getenv('GOOGLE_API_KEY'))

# %%
model=genai.GenerativeModel('gemini-2.5-flash-lite')

# %%
promt='''In the uploaded image.Identify the defected area and mark in the image.Return the image only'''

# %%
import datetime as dt

# %%
print(dt.datetime.now().date())
# Out:
# 2025-09-17

# %%
print(dt.datetime.now().time())
# Out:
# 11:26:02.243919
